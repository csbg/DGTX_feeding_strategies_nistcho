# %%
import subprocess
import os

# %%
# Specify the directory path
base_folder = r"\analysis\cafog" # must be changed to directory where output of 03_prepare_data_cafog.R is saved


# List all directories in the specified path
folder_names = [entry for entry in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, entry))]

# Print the list of folders
print(folder_names)
# Out:
# ['A_1_120', 'A_1_264', 'A_2_120', 'A_2_264', 'A_3_120', 'A_3_264', 'A_4_120', 'A_4_264', 'B_1_120', 'B_1_264', 'B_2_120', 'B_2_264', 'B_3_120', 'B_3_264', 'B_4_120', 'B_4_264', 'C_1_120', 'C_1_240', 'C_2_120', 'C_2_240', 'C_3_120', 'C_3_240', 'C_4_120', 'C_4_240', 'C_4_246', 'D_1_120', 'D_1_264', 'D_2_120', 'D_2_264', 'D_3_120', 'D_3_264', 'E_1_120', 'E_1_264', 'E_2_120', 'E_2_264', 'E_3_120', 'E_3_264', 'F_1_120', 'F_1_264', 'F_2_120', 'F_2_264', 'F_3_120', 'F_3_264', 'G_1_120', 'G_1_240', 'G_2_120', 'G_2_240', 'G_3_120', 'G_3_240', 'G_4_120', 'G_4_240', 'G_4_246']

# %%
# Iterate over each folder name and execute the analysis
for folder_name in folder_names:
    # Construct the command string with updated folder paths
    command = (
        f"python cafog.py "
        f"-f {base_folder}\\{folder_name}\\glycosylation.csv "
        f"-g {base_folder}\\{folder_name}\\glycation.csv "
        f"-l {base_folder}\\{folder_name}\\glycan_library.csv "
        f"> {base_folder}\\{folder_name}\\results.csv"
    )

    # Execute the command using subprocess with shell=True
    try:
        print(f"Analyzing folder: {folder_name}...")
        subprocess.run(command, shell=True, check=True)
        print(f"Analysis of folder {folder_name} completed successfully!")
    except subprocess.CalledProcessError as e:
        print(f"Error analyzing folder {folder_name}: {e}")
# Out:
# Analyzing folder: A_1_120...
# Analysis of folder A_1_120 completed successfully!
# Analyzing folder: A_1_264...
# Analysis of folder A_1_264 completed successfully!
# Analyzing folder: A_2_120...
# Analysis of folder A_2_120 completed successfully!
# Analyzing folder: A_2_264...
# Analysis of folder A_2_264 completed successfully!
# Analyzing folder: A_3_120...
# Analysis of folder A_3_120 completed successfully!
# Analyzing folder: A_3_264...
# Analysis of folder A_3_264 completed successfully!
# Analyzing folder: A_4_120...
# Analysis of folder A_4_120 completed successfully!
# Analyzing folder: A_4_264...
# Analysis of folder A_4_264 completed successfully!
# Analyzing folder: B_1_120...
# Analysis of folder B_1_120 completed successfully!
# Analyzing folder: B_1_264...
# Analysis of folder B_1_264 completed successfully!
# Analyzing folder: B_2_120...
# Analysis of folder B_2_120 completed successfully!
# Analyzing folder: B_2_264...
# Analysis of folder B_2_264 completed successfully!
# Analyzing folder: B_3_120...
# Analysis of folder B_3_120 completed successfully!
# Analyzing folder: B_3_264...
# Analysis of folder B_3_264 completed successfully!
# Analyzing folder: B_4_120...
# Analysis of folder B_4_120 completed successfully!
# Analyzing folder: B_4_264...
# Analysis of folder B_4_264 completed successfully!
# Analyzing folder: C_1_120...
# Analysis of folder C_1_120 completed successfully!
# Analyzing folder: C_1_240...
# Analysis of folder C_1_240 completed successfully!
# Analyzing folder: C_2_120...
# Analysis of folder C_2_120 completed successfully!
# Analyzing folder: C_2_240...
# Analysis of folder C_2_240 completed successfully!
# Analyzing folder: C_3_120...
# Analysis of folder C_3_120 completed successfully!
# Analyzing folder: C_3_240...
# Analysis of folder C_3_240 completed successfully!
# Analyzing folder: C_4_120...
# Analysis of folder C_4_120 completed successfully!
# Analyzing folder: C_4_240...
# Analysis of folder C_4_240 completed successfully!
# Analyzing folder: C_4_246...
# Analysis of folder C_4_246 completed successfully!
# Analyzing folder: D_1_120...
# Analysis of folder D_1_120 completed successfully!
# Analyzing folder: D_1_264...
# Analysis of folder D_1_264 completed successfully!
# Analyzing folder: D_2_120...
# Analysis of folder D_2_120 completed successfully!
# Analyzing folder: D_2_264...
# Analysis of folder D_2_264 completed successfully!
# Analyzing folder: D_3_120...
# Analysis of folder D_3_120 completed successfully!
# Analyzing folder: D_3_264...
# Analysis of folder D_3_264 completed successfully!
# Analyzing folder: E_1_120...
# Analysis of folder E_1_120 completed successfully!
# Analyzing folder: E_1_264...
# Analysis of folder E_1_264 completed successfully!
# Analyzing folder: E_2_120...
# Analysis of folder E_2_120 completed successfully!
# Analyzing folder: E_2_264...
# Analysis of folder E_2_264 completed successfully!
# Analyzing folder: E_3_120...
# Analysis of folder E_3_120 completed successfully!
# Analyzing folder: E_3_264...
# Analysis of folder E_3_264 completed successfully!
# Analyzing folder: F_1_120...
# Analysis of folder F_1_120 completed successfully!
# Analyzing folder: F_1_264...
# Analysis of folder F_1_264 completed successfully!
# Analyzing folder: F_2_120...
# Analysis of folder F_2_120 completed successfully!
# Analyzing folder: F_2_264...
# Analysis of folder F_2_264 completed successfully!
# Analyzing folder: F_3_120...
# Analysis of folder F_3_120 completed successfully!
# Analyzing folder: F_3_264...
# Analysis of folder F_3_264 completed successfully!
# Analyzing folder: G_1_120...
# Analysis of folder G_1_120 completed successfully!
# Analyzing folder: G_1_240...
# Analysis of folder G_1_240 completed successfully!
# Analyzing folder: G_2_120...
# Analysis of folder G_2_120 completed successfully!
# Analyzing folder: G_2_240...
# Analysis of folder G_2_240 completed successfully!
# Analyzing folder: G_3_120...
# Analysis of folder G_3_120 completed successfully!
# Analyzing folder: G_3_240...
# Analysis of folder G_3_240 completed successfully!
# Analyzing folder: G_4_120...
# Analysis of folder G_4_120 completed successfully!
# Analyzing folder: G_4_240...
# Analysis of folder G_4_240 completed successfully!
# Analyzing folder: G_4_246...
# Analysis of folder G_4_246 completed successfully!
